# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0           katsuura  35.1333  140.3000    278.16        80
# 1        1            susuman  62.7833  148.1667    239.81       100
# 2        2             albany  42.6001  -73.9662    275.38        69
# 3        3        bandarbeyla   9.4942   50.8122    298.69        67
# 4        4  port-aux-francais -49.3500   70.2167    277.87        74
#
#    Cloudiness  Wind Speed Country        Date
# 0          99        3.74      JP  1707351214
# 1          98        0.89      RU  1707351214
# 2          68        0.73      US  1707351215
# 3          49        7.48      SO  1707351215
# 4          94       12.61      TF  1707351215

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_map = city_data_df.hvplot.points("Lng","Lat",geo=True,tiles = "OSM",color = "City",size="Humidity")

# Display the map
city_data_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#set ideal conditions and use to filter city dataframe
ideal_temp = 290
ideal_humidity = 60
ideal_cloudiness = 50
ideal_wind = 10

ideal_cities_df = city_data_df.loc[(city_data_df["Max Temp"]>ideal_temp)&(city_data_df["Humidity"]<ideal_humidity)&(city_data_df["Cloudiness"]<ideal_cloudiness)&(city_data_df["Wind Speed"]<ideal_wind)]
# Drop any rows with null values
ideal_cities_df.dropna()

# Display sample data
ideal_cities_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 26        26            aleg  17.0481  -13.9209    299.12         9
# 46        46         yanchep -31.5500  115.6833    302.56        25
# 62        62  margaret river -33.9500  115.0667    296.72        40
# 88        88       carnarvon -24.8667  113.6333    301.42        51
# 96        96         akjoujt  19.6969  -14.4164    296.29         9
# 120      120           kiffa  16.6166  -11.4045    297.26         9
# 218      218      san julian  21.0167 -102.1667    296.45        15
# 227      227     east london -33.0153   27.9116    293.33        59
# 241      241       geraldton -28.7667  114.6000    305.38        13
# 244      244   bamnet narong  15.4992  101.6897    295.55        45
# 261      261     broken hill -31.9500  141.4333    297.87        28
# 275      275       tazacorte  28.6290  -17.9293    292.68        21
# 314      314       ar ruways  24.1103   52.7306    290.65        56
# 319      319         dunedin -45.8742  170.5036    293.04        44
# 320      320   mount gambier -37.8333  140.7667    292.68        48
# 326      326          ouadda   8.0777   22.4007    292.73        27
# 356      356         ouallam  14.3188    2.0866    293.43        12
# 361      361      bell ville -32.6259  -62.6887    305.74        26
# 383      383         quthing -30.4000   27.7003    290.95        30
# 384      384          tougan  13.0667   -3.0667    295.93        12
# 411      411         banamba  13.5500   -7.4500    296.21        11
# 452      452           umluj  25.0213   37.2685    295.94        29
# 469      469  tchintabaraden  15.8969    5.7985    290.71        16
# 475      475  cabo san lucas  22.8909 -109.9124    297.93        52
# 483      483       taoudenni  22.6783   -3.9836    291.96        15
# 495      495          lodwar   3.1191   35.5973    303.37        41
# 506      506         temozon  20.8000  -88.2167    299.20        54
# 523      523         pagouda   9.7525    1.3278    298.28        18
# 540      540          nicoya  10.1483  -85.4520    299.24        54
# 545      545    port hedland -20.3167  118.5667    305.18        25
# 547      547     tekkalakote  15.5333   76.8833    296.35        45
#
#      Cloudiness  Wind Speed Country        Date
# 26            0        4.68      MR  1707351225
# 46            0        5.60      AU  1707351233
# 62            0        1.25      AU  1707351240
# 88            0        2.27      AU  1707351254
# 96            7        4.10      MR  1707351256
# 120           0        4.73      MR  1707351268
# 218          12        4.76      MX  1707351308
# 227           0        3.69      ZA  1707351313
# 241           0        9.77      AU  1707351319
# 244          27        3.12      TH  1707351320
# 261           1        8.20      AU  1707351157
# 275           0        4.02      ES  1707351333
# 314           0        5.59      AE  1707351350
# 319           6        4.47      NZ  1707351352
# 320          27        2.91      AU  1707351251
# 326          44        2.41      CF  1707351355
# 356          22        5.58      NE  1707351374
# 361          34        3.78      AR  1707351382
# 383           0        1.60      LS  1707351318
# 384          26        4.16      BF  1707351394
# 411          48        4.13      ML  1707351405
# 452           0        5.72      SA  1707351422
# 469          14        4.23      NE  1707351430
# 475          20        5.36      MX  1707351432
# 483           3        4.23      ML  1707351435
# 495          13        2.93      KE  1707351440
# 506          12        2.73      MX  1707351445
# 523           6        3.27      TG  1707351453
# 540          17        4.60      CR  1707351460
# 545          22        3.60      AU  1707351319
# 547           2        1.80      IN  1707351463

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df[["City","Country","Lat","Lng","Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 26             aleg      MR  17.0481  -13.9209         9
# 46          yanchep      AU -31.5500  115.6833        25
# 62   margaret river      AU -33.9500  115.0667        40
# 88        carnarvon      AU -24.8667  113.6333        51
# 96          akjoujt      MR  19.6969  -14.4164         9
# 120           kiffa      MR  16.6166  -11.4045         9
# 218      san julian      MX  21.0167 -102.1667        15
# 227     east london      ZA -33.0153   27.9116        59
# 241       geraldton      AU -28.7667  114.6000        13
# 244   bamnet narong      TH  15.4992  101.6897        45
# 261     broken hill      AU -31.9500  141.4333        28
# 275       tazacorte      ES  28.6290  -17.9293        21
# 314       ar ruways      AE  24.1103   52.7306        56
# 319         dunedin      NZ -45.8742  170.5036        44
# 320   mount gambier      AU -37.8333  140.7667        48
# 326          ouadda      CF   8.0777   22.4007        27
# 356         ouallam      NE  14.3188    2.0866        12
# 361      bell ville      AR -32.6259  -62.6887        26
# 383         quthing      LS -30.4000   27.7003        30
# 384          tougan      BF  13.0667   -3.0667        12
# 411         banamba      ML  13.5500   -7.4500        11
# 452           umluj      SA  25.0213   37.2685        29
# 469  tchintabaraden      NE  15.8969    5.7985        16
# 475  cabo san lucas      MX  22.8909 -109.9124        52
# 483       taoudenni      ML  22.6783   -3.9836        15
# 495          lodwar      KE   3.1191   35.5973        41
# 506         temozon      MX  20.8000  -88.2167        54
# 523         pagouda      TG   9.7525    1.3278        18
# 540          nicoya      CR  10.1483  -85.4520        54
# 545    port hedland      AU -20.3167  118.5667        25
# 547     tekkalakote      IN  15.5333   76.8833        45

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel","apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    long = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{long},{lat},{radius}"
    params["bias"] = f"proximity:{long},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# aleg - nearest hotel: Hotel Oasis Aleg
# yanchep - nearest hotel: Yanchep Inn
# margaret river - nearest hotel: Margaret River Hotel
# carnarvon - nearest hotel: No hotel found
# akjoujt - nearest hotel: فندق فاطمة
# kiffa - nearest hotel: فندق كيفة
# san julian - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# geraldton - nearest hotel: Ocean Centre Hotel
# bamnet narong - nearest hotel: Racha & Glenn Andersson
# broken hill - nearest hotel: Ibis Styles
# tazacorte - nearest hotel: App Leyma
# ar ruways - nearest hotel: No hotel found
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# ouadda - nearest hotel: No hotel found
# ouallam - nearest hotel: No hotel found
# bell ville - nearest hotel: No hotel found
# quthing - nearest hotel: Mountainside Hotel
# tougan - nearest hotel: Hotel ZEELA
# banamba - nearest hotel: No hotel found
# umluj - nearest hotel: No hotel found
# tchintabaraden - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: Comfort Rooms
# taoudenni - nearest hotel: No hotel found
# lodwar - nearest hotel: Lodwar Modern Lodge
# temozon - nearest hotel: Hotel Villa Lupita
# pagouda - nearest hotel: No hotel found
# nicoya - nearest hotel: Hotel marianela
# port hedland - nearest hotel: The Esplanade Hotel
# tekkalakote - nearest hotel: No hotel found
#                City Country      Lat       Lng  Humidity  \
# 26             aleg      MR  17.0481  -13.9209         9
# 46          yanchep      AU -31.5500  115.6833        25
# 62   margaret river      AU -33.9500  115.0667        40
# 88        carnarvon      AU -24.8667  113.6333        51
# 96          akjoujt      MR  19.6969  -14.4164         9
# 120           kiffa      MR  16.6166  -11.4045         9
# 218      san julian      MX  21.0167 -102.1667        15
# 227     east london      ZA -33.0153   27.9116        59
# 241       geraldton      AU -28.7667  114.6000        13
# 244   bamnet narong      TH  15.4992  101.6897        45
# 261     broken hill      AU -31.9500  141.4333        28
# 275       tazacorte      ES  28.6290  -17.9293        21
# 314       ar ruways      AE  24.1103   52.7306        56
# 319         dunedin      NZ -45.8742  170.5036        44
# 320   mount gambier      AU -37.8333  140.7667        48
# 326          ouadda      CF   8.0777   22.4007        27
# 356         ouallam      NE  14.3188    2.0866        12
# 361      bell ville      AR -32.6259  -62.6887        26
# 383         quthing      LS -30.4000   27.7003        30
# 384          tougan      BF  13.0667   -3.0667        12
# 411         banamba      ML  13.5500   -7.4500        11
# 452           umluj      SA  25.0213   37.2685        29
# 469  tchintabaraden      NE  15.8969    5.7985        16
# 475  cabo san lucas      MX  22.8909 -109.9124        52
# 483       taoudenni      ML  22.6783   -3.9836        15
# 495          lodwar      KE   3.1191   35.5973        41
# 506         temozon      MX  20.8000  -88.2167        54
# 523         pagouda      TG   9.7525    1.3278        18
# 540          nicoya      CR  10.1483  -85.4520        54
# 545    port hedland      AU -20.3167  118.5667        25
# 547     tekkalakote      IN  15.5333   76.8833        45
#
#                      Hotel Name
# 26             Hotel Oasis Aleg
# 46                  Yanchep Inn
# 62         Margaret River Hotel
# 88               No hotel found
# 96                   فندق فاطمة
# 120                   فندق كيفة
# 218              No hotel found
# 227              No hotel found
# 241          Ocean Centre Hotel
# 244     Racha & Glenn Andersson
# 261                 Ibis Styles
# 275                   App Leyma
# 314              No hotel found
# 319   Scenic Hotel Dunedin City
# 320  The Old Mount Gambier Gaol
# 326              No hotel found
# 356              No hotel found
# 361              No hotel found
# 383          Mountainside Hotel
# 384                 Hotel ZEELA
# 411              No hotel found
# 452              No hotel found
# 469              No hotel found
# 475               Comfort Rooms
# 483              No hotel found
# 495         Lodwar Modern Lodge
# 506          Hotel Villa Lupita
# 523              No hotel found
# 540             Hotel marianela
# 545         The Esplanade Hotel
# 547              No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng","Lat",geo=True,tiles = "OSM",color = "City",size="Humidity",hover_cols = ["Hotel Name","Country"])

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
